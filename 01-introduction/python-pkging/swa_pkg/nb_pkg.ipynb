# %%
from swa.utils.weather import get_wheather_conditions

r = get_wheather_conditions(citi_name="paris")

# %%
print(r)
# Out:
# Weather report: paris
#
#       \   /     Sunny
#        .-.      +5(4) °C
#     ― (   ) ―   ← 7 km/h
#        `-’      10 km
#       /   \     0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 14 Jan ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │     \   /     Clear          │     \   /     Clear          │
# │      .-.      +2(1) °C       │      .-.      +9(8) °C       │      .-.      +9(8) °C       │      .-.      +5(4) °C       │
# │   ― (   ) ―   ← 6-12 km/h    │   ― (   ) ―   ← 6-7 km/h     │   ― (   ) ―   ← 6 km/h       │   ― (   ) ―   ← 5-10 km/h    │
# ...
